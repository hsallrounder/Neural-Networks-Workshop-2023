# %% [markdown]
# <a href="https://colab.research.google.com/github/hsallrounder/Neural-Networks-Workshop-2023/blob/main/HeartDiseaseTensorflow_Neural_Networks_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import pandas as pd

# %%
def load_data():
    train_dataset = pd.read_csv('https://raw.githubusercontent.com/tommasodeponti/Datasets/master/heart_train.csv')
    test_dataset = pd.read_csv('https://raw.githubusercontent.com/tommasodeponti/Datasets/master/heart_test.csv')
    train_columns = train_dataset.columns
    train_predictors = train_dataset[train_columns[train_columns != 'target']]
    train_target = train_dataset['target']

    test_columns = test_dataset.columns
    test_predictors = test_dataset[test_columns[test_columns != 'target']]
    test_target = test_dataset['target']

    X_train = train_predictors
    y_train = train_target

    X_test = test_predictors
    y_test = test_target

    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    return X_train, y_train, X_test, y_test

# %%
def build_model():
    model = Sequential()
    model.add(Dense(200, activation='relu', input_shape=(X_train.shape[1],)))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(2, activation='softmax'))

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
X_train, y_train, X_test, y_test = load_data()

model = build_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 9/9 - 5s - loss: 2.6883 - accuracy: 0.5019 - val_loss: 0.7420 - val_accuracy: 0.6667 - 5s/epoch - 505ms/step
# Epoch 2/200
# 9/9 - 0s - loss: 0.9369 - accuracy: 0.5326 - val_loss: 0.7023 - val_accuracy: 0.6190 - 423ms/epoch - 47ms/step
# Epoch 3/200
# 9/9 - 0s - loss: 0.6501 - accuracy: 0.6705 - val_loss: 0.5839 - val_accuracy: 0.7143 - 264ms/epoch - 29ms/step
# Epoch 4/200
# 9/9 - 0s - loss: 0.6046 - accuracy: 0.6590 - val_loss: 0.5986 - val_accuracy: 0.6429 - 230ms/epoch - 26ms/step
# Epoch 5/200
# 9/9 - 0s - loss: 0.6168 - accuracy: 0.6743 - val_loss: 0.6027 - val_accuracy: 0.6905 - 185ms/epoch - 21ms/step
# Epoch 6/200
# 9/9 - 0s - loss: 0.6055 - accuracy: 0.6743 - val_loss: 0.7258 - val_accuracy: 0.5952 - 231ms/epoch - 26ms/step
# Epoch 7/200
# 9/9 - 0s - loss: 0.6997 - accuracy: 0.6552 - val_loss: 0.6303 - val_accuracy: 0.6905 - 269ms/epoch - 30ms/step
# Epoch 8/200
# ...

# %%
scores = model.evaluate(X_test, y_test)
print(f'Accuracy: {scores[1]} \n Error: {1 - scores[1]}')
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3380 - accuracy: 0.7857
# Accuracy: 0.7857142686843872
#  Error: 0.2142857313156128

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import pandas as pd


def load_data():
    train_dataset = pd.read_csv('https://raw.githubusercontent.com/tommasodeponti/Datasets/master/heart_train.csv')
    test_dataset = pd.read_csv('https://raw.githubusercontent.com/tommasodeponti/Datasets/master/heart_test.csv')
    train_columns = train_dataset.columns
    train_predictors = train_dataset[train_columns[train_columns != 'target']]
    train_target = train_dataset['target']

    test_columns = test_dataset.columns
    test_predictors = test_dataset[test_columns[test_columns != 'target']]
    test_target = test_dataset['target']

    X_train = train_predictors
    y_train = train_target

    X_test = test_predictors
    y_test = test_target

    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    return X_train, y_train, X_test, y_test


def build_model():
    model = Sequential()
    model.add(Dense(200, activation='relu', input_shape=(X_train.shape[1],)))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(2, activation='softmax'))

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model


X_train, y_train, X_test, y_test = load_data()

# print(f"Train \n{X_train} \n\n")
# print(f"Test \n{X_test} \n\n")
# print(f"ytrain \n{y_train} \n\n")
# print(f"ytest \n{y_test} \n\n")

model = build_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=200, verbose=2)

scores = model.evaluate(X_test, y_test)
print(f'Accuracy: {scores[1]} \n Error: {1 - scores[1]}')
# Out:
# Epoch 1/200
# 9/9 - 1s - loss: 2.7450 - accuracy: 0.5364 - val_loss: 0.7037 - val_accuracy: 0.6429 - 1s/epoch - 156ms/step
# Epoch 2/200
# 9/9 - 0s - loss: 0.7750 - accuracy: 0.6513 - val_loss: 0.7938 - val_accuracy: 0.6190 - 71ms/epoch - 8ms/step
# Epoch 3/200
# 9/9 - 0s - loss: 0.7596 - accuracy: 0.6207 - val_loss: 0.8747 - val_accuracy: 0.5476 - 91ms/epoch - 10ms/step
# Epoch 4/200
# 9/9 - 0s - loss: 0.7808 - accuracy: 0.6322 - val_loss: 0.5806 - val_accuracy: 0.7143 - 82ms/epoch - 9ms/step
# Epoch 5/200
# 9/9 - 0s - loss: 0.8655 - accuracy: 0.5862 - val_loss: 0.7791 - val_accuracy: 0.5952 - 93ms/epoch - 10ms/step
# Epoch 6/200
# 9/9 - 0s - loss: 0.7269 - accuracy: 0.6360 - val_loss: 0.7392 - val_accuracy: 0.5714 - 71ms/epoch - 8ms/step
# Epoch 7/200
# 9/9 - 0s - loss: 0.6310 - accuracy: 0.6705 - val_loss: 0.6419 - val_accuracy: 0.6190 - 75ms/epoch - 8ms/step
# Epoch 8/200
# ...

# %% [markdown]
# 1. Car Loan Prediction
# 2. Bank Emi Prediction using decision Tree
# 3. Cancer Detection
# 4. Covid Case Using SVM
# 5. Covid Case Using ANN
# 6. Online Course Recommandation
# 7. Breast Cancer Prediction using RNN
# 8. Movie Recommandation System using RNN Function
# 9. Fake NEws Detection Comparing 2 Algorithms
# 10. Plant Disease Prediction Using CNN
# 11. Plant Disease Prediction Using SVM
# 12. Heart Disease Prediction Using Classified Algorithm
# 13. Plant Classification Using ANN
# 14. Plant Classification Using CNN
# 15. Student Feedback System Using PyTorch
# 16. Daily USer Analysis
# 17. Sentiment Analysis Using ANN
